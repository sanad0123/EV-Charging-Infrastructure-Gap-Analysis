# %% [markdown]
# # Some EDA

# %%
import geopandas as gpd
import pandas as pd
import os

# %%
df = pd.read_csv('data_processed/final_combined/all_states_final_model_table.csv')
df.head()
# Out:
#         GEOID  population  households  median_income  workers  \
# 0  6029004402      4667.0      1316.0        29515.0   1947.0
# 1  6047000802      4597.0      1532.0        77143.0   2354.0
# 2  6085501402      2716.0       839.0        93092.0   1458.0
# 3  6005000102      2338.0       960.0        69500.0    993.0
# 4  6029004901      6074.0      1602.0        47167.0   2889.0
#
#    mean_commute_time  vehicles_total state  county     tract  ...  \
# 0             1723.0          1316.0    CA    29.0    4402.0  ...
# 1             1884.0          1532.0    CA    47.0     802.0  ...
# 2             1222.0           839.0    CA    85.0  501402.0  ...
# 3              690.0           960.0    CA     5.0     102.0  ...
# 4             2439.0          1602.0    CA    29.0    4901.0  ...
#
#   station_count  total_ports  l2_ports  dcfc_ports  dist_nearest_charger_km  \
# 0             2            2         0           2                 0.146392
# ...

# %%
df.describe()
# Out:
#               GEOID    population    households  median_income       workers  \
# count  1.637100e+04  16371.000000  16371.000000   16001.000000  16371.000000
# mean   1.670232e+10   4041.293201   1466.053082   99785.846135   2096.152465
# std    1.438315e+10   1787.142892    662.720656   45875.778450   1004.746846
# min    6.001400e+09      0.000000      0.000000    2499.000000      0.000000
# 25%    6.053001e+09   2811.500000   1023.000000   67171.000000   1422.500000
# 50%    6.085512e+09   3899.000000   1404.000000   90859.000000   2013.000000
# 75%    3.604703e+10   5083.500000   1844.500000  122708.000000   2666.000000
# max    5.002797e+10  40481.000000   8336.000000  250001.000000  28566.000000
#
#        mean_commute_time  vehicles_total        county          tract  \
# count       16371.000000    16371.000000  16371.000000   16371.000000
# mean         1623.120396     1466.053082     55.514202  170591.077637
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16371 entries, 0 to 16370
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   GEOID                    16371 non-null  int64
#  1   population               16371 non-null  float64
#  2   households               16371 non-null  float64
#  3   median_income            16001 non-null  float64
#  4   workers                  16371 non-null  float64
#  5   mean_commute_time        16371 non-null  float64
#  6   vehicles_total           16371 non-null  float64
#  7   state                    16371 non-null  str
#  8   county                   16371 non-null  float64
#  9   tract                    16371 non-null  float64
#  10  state_code               16371 non-null  str
#  11  station_count            16371 non-null  int64
#  12  total_ports              16371 non-null  int64
#  13  l2_ports                 16371 non-null  int64
# ...

# %%
df["establishments_total"].hist(bins=50)
# Out:
# <Axes: >

# %%
df["dist_nearest_charger_km"].hist(bins=50)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_cols = [
    "population",
    "median_income",
    "establishments_total",
    "retail_establishments",
    "food_establishments",
    "dist_nearest_charger_km",
    "station_count",
    "total_ports"
]

corr = df[corr_cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()
