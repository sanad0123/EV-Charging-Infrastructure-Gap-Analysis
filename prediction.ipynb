# %%
from Pipeline.prediction_pipeline import EVCompleteStatePipeline

pipeline = EVCompleteStatePipeline()

# %%
pipeline.run("WA")
# Out:
# 2026-02-25 21:47:14,509 - INFO - Processing WA
# 2026-02-25 21:47:14,510 - INFO - Downloading TIGER tracts for WA
# ========== PROCESSING WA ==========
#
# Running main data pipeline...
# 2026-02-25 21:47:20,746 - WARNING - Skipping field funding_sources: unsupported OGR type: 5
# 2026-02-25 21:47:20,746 - WARNING - Skipping field ev_connector_types: unsupported OGR type: 5
# 2026-02-25 21:47:26,140 - INFO - Allocating ZBP to tracts
# /Users/sanjeebadhikari/miniconda3/envs/ev_gap_env/lib/python3.12/site-packages/geopandas/tools/overlay.py:358: UserWarning: `keep_geom_type=True` in overlay resulted in 25326 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   result = _collection_extract(result, geom_type, keep_geom_type_warning)
# 2026-02-25 21:47:42,580 - INFO - Created 1,784 records
# 2026-02-25 21:47:42,595 - INFO - WA dataset saved.
# 2026-02-25 21:47:42,705 - INFO - Processing WA
# ...
